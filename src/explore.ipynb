# %% [markdown]
# # Explore here

# %%
import os
import pandas as pd
import seaborn as sns
from dotenv import load_dotenv
import spotipy
from spotipy.oauth2 import SpotifyOAuth

# load the .env file variables
load_dotenv()

client_id = os.environ.get("CLIENT_ID")
client_secret = os.environ.get("CLIENT_SECRET")


sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=client_id,client_secret=client_secret,redirect_uri='https://localhost'))

# %%
id_artista = '64tNsm6TnZe2zpcMVMOoHL'

respuesta = sp.artist_top_tracks(id_artista)

tracks = respuesta['tracks']

# %%
df_tracks = pd.DataFrame.from_records(tracks)

df_tracks
# Out:
#                                                album  \
# 0  {'album_type': 'album', 'artists': [{'external...
# 1  {'album_type': 'album', 'artists': [{'external...
# 2  {'album_type': 'album', 'artists': [{'external...
# 3  {'album_type': 'album', 'artists': [{'external...
# 4  {'album_type': 'album', 'artists': [{'external...
# 5  {'album_type': 'album', 'artists': [{'external...
# 6  {'album_type': 'album', 'artists': [{'external...
# 7  {'album_type': 'album', 'artists': [{'external...
# 8  {'album_type': 'album', 'artists': [{'external...
# 9  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  disc_number  \
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# 4  [{'external_urls': {'spotify': 'https://open.s...            1
# 5  [{'external_urls': {'spotify': 'https://open.s...            1
# 6  [{'external_urls': {'spotify': 'https://open.s...            1
# 7  [{'external_urls': {'spotify': 'https://open.s...            1
# 8  [{'external_urls': {'spotify': 'https://open.s...            1
# 9  [{'external_urls': {'spotify': 'https://open.s...            1
#
#    duration_ms  explicit              external_ids  \
# 0       285200      True  {'isrc': 'USSM19000727'}
# 1       206773     False  {'isrc': 'USSM19200805'}
# 2       259200     False  {'isrc': 'USSM10025671'}
# 3       374333     False  {'isrc': 'USSM19200881'}
# 4       149466     False  {'isrc': 'USSM19200799'}
# 5       338226     False  {'isrc': 'USSM10023130'}
# 6       152560     False  {'isrc': 'USSM19000767'}
# 7       255573     False  {'isrc': 'USSM19303748'}
# 8       418466     False  {'isrc': 'USSM10024569'}
# 9       254400     False  {'isrc': 'USSM19303749'}
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/6g...
# 1  {'spotify': 'https://open.spotify.com/track/5s...
# 2  {'spotify': 'https://open.spotify.com/track/2J...
# 3  {'spotify': 'https://open.spotify.com/track/0w...
# 4  {'spotify': 'https://open.spotify.com/track/4A...
# 5  {'spotify': 'https://open.spotify.com/track/7F...
# 6  {'spotify': 'https://open.spotify.com/track/5D...
# 7  {'spotify': 'https://open.spotify.com/track/4P...
# 8  {'spotify': 'https://open.spotify.com/track/7F...
# 9  {'spotify': 'https://open.spotify.com/track/6H...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/tracks/6gZVQvQZOFpz...  6gZVQvQZOFpzIy3HblJ20F
# 1  https://api.spotify.com/v1/tracks/5sFDReWLrZHL...  5sFDReWLrZHLFZFjHsjUTS
# 2  https://api.spotify.com/v1/tracks/2JuasWPUodaU...  2JuasWPUodaUxf5nwNpciQ
# 3  https://api.spotify.com/v1/tracks/0wvIGFIgbyz4...  0wvIGFIgbyz4JNwQhZgTv2
# 4  https://api.spotify.com/v1/tracks/4A065x9kJt95...  4A065x9kJt955eGVqf813g
# 5  https://api.spotify.com/v1/tracks/7FRfYOql61DG...  7FRfYOql61DGDp9VPPe2qA
# 6  https://api.spotify.com/v1/tracks/5Ds35L9KpUDK...  5Ds35L9KpUDKgSxZ6whuoQ
# 7  https://api.spotify.com/v1/tracks/4PtZE0h5oyPh...  4PtZE0h5oyPhCtPjg3NeYQ
# 8  https://api.spotify.com/v1/tracks/7Fm3NhbAYHvT...  7Fm3NhbAYHvTQUhboim9FB
# 9  https://api.spotify.com/v1/tracks/6HnZsLUDrG3H...  6HnZsLUDrG3HTSbh8sq2u3
#
#    is_local  is_playable                            name  popularity  \
# 0     False         True                  Man in the Box          77
# 1     False         True          Would? (2022 Remaster)          75
# 2     False         True                        Nutshell          73
# 3     False         True         Rooster (2022 Remaster)          71
# 4     False         True      Them Bones (2022 Remaster)          70
# 5     False         True  Down In A Hole (2022 Remaster)          66
# 6     False         True                    We Die Young          65
# 7     False         True                      No Excuses          64
# 8     False         True                    Rotten Apple          63
# 9     False         True                     I Stay Away          63
#
#                                          preview_url  track_number   type  \
# 0  https://p.scdn.co/mp3-preview/68dbc11f83265b4e...             2  track
# 1  https://p.scdn.co/mp3-preview/1343c561e5b037af...            13  track
# 2  https://p.scdn.co/mp3-preview/7a7a6de35de30957...             2  track
# 3  https://p.scdn.co/mp3-preview/a3f28e30b42a5f4b...             6  track
# 4  https://p.scdn.co/mp3-preview/d4cc42320063ee1d...             1  track
# 5  https://p.scdn.co/mp3-preview/15e0e21257358920...             4  track
# 6  https://p.scdn.co/mp3-preview/3ecb87ba14d0a777...             1  track
# 7  https://p.scdn.co/mp3-preview/f7daa62fbd3b718a...             4  track
# 8  https://p.scdn.co/mp3-preview/da9ffbbe38cc5864...             1  track
# 9  https://p.scdn.co/mp3-preview/b40cca2dc4f4a5f1...             3  track
#
#                                     uri
# 0  spotify:track:6gZVQvQZOFpzIy3HblJ20F
# 1  spotify:track:5sFDReWLrZHLFZFjHsjUTS
# 2  spotify:track:2JuasWPUodaUxf5nwNpciQ
# 3  spotify:track:0wvIGFIgbyz4JNwQhZgTv2
# 4  spotify:track:4A065x9kJt955eGVqf813g
# 5  spotify:track:7FRfYOql61DGDp9VPPe2qA
# 6  spotify:track:5Ds35L9KpUDKgSxZ6whuoQ
# 7  spotify:track:4PtZE0h5oyPhCtPjg3NeYQ
# 8  spotify:track:7Fm3NhbAYHvTQUhboim9FB
# 9  spotify:track:6HnZsLUDrG3HTSbh8sq2u3

# %%
df_tracks.sort_values(['popularity'],inplace=True)
df_tracks
# Out:
#                                                album  \
# 8  {'album_type': 'album', 'artists': [{'external...
# 9  {'album_type': 'album', 'artists': [{'external...
# 7  {'album_type': 'album', 'artists': [{'external...
# 6  {'album_type': 'album', 'artists': [{'external...
# 5  {'album_type': 'album', 'artists': [{'external...
# 4  {'album_type': 'album', 'artists': [{'external...
# 3  {'album_type': 'album', 'artists': [{'external...
# 2  {'album_type': 'album', 'artists': [{'external...
# 1  {'album_type': 'album', 'artists': [{'external...
# 0  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  disc_number  \
# 8  [{'external_urls': {'spotify': 'https://open.s...            1
# 9  [{'external_urls': {'spotify': 'https://open.s...            1
# 7  [{'external_urls': {'spotify': 'https://open.s...            1
# 6  [{'external_urls': {'spotify': 'https://open.s...            1
# 5  [{'external_urls': {'spotify': 'https://open.s...            1
# 4  [{'external_urls': {'spotify': 'https://open.s...            1
# 3  [{'external_urls': {'spotify': 'https://open.s...            1
# 2  [{'external_urls': {'spotify': 'https://open.s...            1
# 1  [{'external_urls': {'spotify': 'https://open.s...            1
# 0  [{'external_urls': {'spotify': 'https://open.s...            1
#
#    duration_ms  explicit              external_ids  \
# 8       418466     False  {'isrc': 'USSM10024569'}
# 9       254400     False  {'isrc': 'USSM19303749'}
# 7       255573     False  {'isrc': 'USSM19303748'}
# 6       152560     False  {'isrc': 'USSM19000767'}
# 5       338226     False  {'isrc': 'USSM10023130'}
# 4       149466     False  {'isrc': 'USSM19200799'}
# 3       374333     False  {'isrc': 'USSM19200881'}
# 2       259200     False  {'isrc': 'USSM10025671'}
# 1       206773     False  {'isrc': 'USSM19200805'}
# 0       285200      True  {'isrc': 'USSM19000727'}
#
#                                        external_urls  \
# 8  {'spotify': 'https://open.spotify.com/track/7F...
# 9  {'spotify': 'https://open.spotify.com/track/6H...
# 7  {'spotify': 'https://open.spotify.com/track/4P...
# 6  {'spotify': 'https://open.spotify.com/track/5D...
# 5  {'spotify': 'https://open.spotify.com/track/7F...
# 4  {'spotify': 'https://open.spotify.com/track/4A...
# 3  {'spotify': 'https://open.spotify.com/track/0w...
# 2  {'spotify': 'https://open.spotify.com/track/2J...
# 1  {'spotify': 'https://open.spotify.com/track/5s...
# 0  {'spotify': 'https://open.spotify.com/track/6g...
#
#                                                 href                      id  \
# 8  https://api.spotify.com/v1/tracks/7Fm3NhbAYHvT...  7Fm3NhbAYHvTQUhboim9FB
# 9  https://api.spotify.com/v1/tracks/6HnZsLUDrG3H...  6HnZsLUDrG3HTSbh8sq2u3
# 7  https://api.spotify.com/v1/tracks/4PtZE0h5oyPh...  4PtZE0h5oyPhCtPjg3NeYQ
# 6  https://api.spotify.com/v1/tracks/5Ds35L9KpUDK...  5Ds35L9KpUDKgSxZ6whuoQ
# 5  https://api.spotify.com/v1/tracks/7FRfYOql61DG...  7FRfYOql61DGDp9VPPe2qA
# 4  https://api.spotify.com/v1/tracks/4A065x9kJt95...  4A065x9kJt955eGVqf813g
# 3  https://api.spotify.com/v1/tracks/0wvIGFIgbyz4...  0wvIGFIgbyz4JNwQhZgTv2
# 2  https://api.spotify.com/v1/tracks/2JuasWPUodaU...  2JuasWPUodaUxf5nwNpciQ
# 1  https://api.spotify.com/v1/tracks/5sFDReWLrZHL...  5sFDReWLrZHLFZFjHsjUTS
# 0  https://api.spotify.com/v1/tracks/6gZVQvQZOFpz...  6gZVQvQZOFpzIy3HblJ20F
#
#    is_local  is_playable                            name  popularity  \
# 8     False         True                    Rotten Apple          63
# 9     False         True                     I Stay Away          63
# 7     False         True                      No Excuses          64
# 6     False         True                    We Die Young          65
# 5     False         True  Down In A Hole (2022 Remaster)          66
# 4     False         True      Them Bones (2022 Remaster)          70
# 3     False         True         Rooster (2022 Remaster)          71
# 2     False         True                        Nutshell          73
# 1     False         True          Would? (2022 Remaster)          75
# 0     False         True                  Man in the Box          77
#
#                                          preview_url  track_number   type  \
# 8  https://p.scdn.co/mp3-preview/da9ffbbe38cc5864...             1  track
# 9  https://p.scdn.co/mp3-preview/b40cca2dc4f4a5f1...             3  track
# 7  https://p.scdn.co/mp3-preview/f7daa62fbd3b718a...             4  track
# 6  https://p.scdn.co/mp3-preview/3ecb87ba14d0a777...             1  track
# 5  https://p.scdn.co/mp3-preview/15e0e21257358920...             4  track
# 4  https://p.scdn.co/mp3-preview/d4cc42320063ee1d...             1  track
# 3  https://p.scdn.co/mp3-preview/a3f28e30b42a5f4b...             6  track
# 2  https://p.scdn.co/mp3-preview/7a7a6de35de30957...             2  track
# 1  https://p.scdn.co/mp3-preview/1343c561e5b037af...            13  track
# 0  https://p.scdn.co/mp3-preview/68dbc11f83265b4e...             2  track
#
#                                     uri
# 8  spotify:track:7Fm3NhbAYHvTQUhboim9FB
# 9  spotify:track:6HnZsLUDrG3HTSbh8sq2u3
# 7  spotify:track:4PtZE0h5oyPhCtPjg3NeYQ
# 6  spotify:track:5Ds35L9KpUDKgSxZ6whuoQ
# 5  spotify:track:7FRfYOql61DGDp9VPPe2qA
# 4  spotify:track:4A065x9kJt955eGVqf813g
# 3  spotify:track:0wvIGFIgbyz4JNwQhZgTv2
# 2  spotify:track:2JuasWPUodaUxf5nwNpciQ
# 1  spotify:track:5sFDReWLrZHLFZFjHsjUTS
# 0  spotify:track:6gZVQvQZOFpzIy3HblJ20F

# %%
df_tracks.head(3)
# Out:
#                                                album  \
# 8  {'album_type': 'album', 'artists': [{'external...
# 9  {'album_type': 'album', 'artists': [{'external...
# 7  {'album_type': 'album', 'artists': [{'external...
#
#                                              artists  disc_number  \
# 8  [{'external_urls': {'spotify': 'https://open.s...            1
# 9  [{'external_urls': {'spotify': 'https://open.s...            1
# 7  [{'external_urls': {'spotify': 'https://open.s...            1
#
#    duration_ms  explicit              external_ids  \
# 8       418466     False  {'isrc': 'USSM10024569'}
# 9       254400     False  {'isrc': 'USSM19303749'}
# 7       255573     False  {'isrc': 'USSM19303748'}
#
#                                        external_urls  \
# 8  {'spotify': 'https://open.spotify.com/track/7F...
# 9  {'spotify': 'https://open.spotify.com/track/6H...
# 7  {'spotify': 'https://open.spotify.com/track/4P...
#
#                                                 href                      id  \
# 8  https://api.spotify.com/v1/tracks/7Fm3NhbAYHvT...  7Fm3NhbAYHvTQUhboim9FB
# 9  https://api.spotify.com/v1/tracks/6HnZsLUDrG3H...  6HnZsLUDrG3HTSbh8sq2u3
# 7  https://api.spotify.com/v1/tracks/4PtZE0h5oyPh...  4PtZE0h5oyPhCtPjg3NeYQ
#
#    is_local  is_playable          name  popularity  \
# 8     False         True  Rotten Apple          63
# 9     False         True   I Stay Away          63
# 7     False         True    No Excuses          64
#
#                                          preview_url  track_number   type  \
# 8  https://p.scdn.co/mp3-preview/da9ffbbe38cc5864...             1  track
# 9  https://p.scdn.co/mp3-preview/b40cca2dc4f4a5f1...             3  track
# 7  https://p.scdn.co/mp3-preview/f7daa62fbd3b718a...             4  track
#
#                                     uri
# 8  spotify:track:7Fm3NhbAYHvTQUhboim9FB
# 9  spotify:track:6HnZsLUDrG3HTSbh8sq2u3
# 7  spotify:track:4PtZE0h5oyPhCtPjg3NeYQ

# %%
import matplotlib.pyplot as plt

plt.scatter(x=df_tracks['popularity'],y=df_tracks['duration_ms'])
plt.show()
